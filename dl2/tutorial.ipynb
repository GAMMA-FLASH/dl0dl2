# %%
import os
from eventlist_v4 import Eventlist
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [25, 10]

# %%
filePath = "/home/usergamma/workspace/data/dl0.h5"

# %%
eventlist = Eventlist()
outputdir="/home/usergamma/workspace/data/output"

# %%
eventlist.process_file(filePath, None, outputdir, True, 275, 277)
#eventlist.process_file(filePath, None, outputdir, False)
# Out:
# Processing /home/usergamma/workspace/data/dl0.h5
# Il file '/home/usergamma/workspace/data/output/dl0.dl2.h5' non esiste.
#  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏       | 265/278 [00:00<00:00, 942.44it/s]
# Waveform num. 275 ##############################
# la waveform num. 275 ha i seguenti peaks: [1194] e mean value 135.92 and stdev 3.956463066932384
# integral 6632.640000000002
# integralMM 6638.960000000002
# integralEXP 5768.915539260953
# Waveform num. 276 ##############################
# la waveform num. 276 ha i seguenti peaks: [1196] e mean value 134.77 and stdev 3.854490887263842
# integral 16331.470000000001
# integralMM 16334.053333333331
# integralEXP 14655.84212937476
# Waveform num. 277 ##############################
# la waveform num. 277 ha i seguenti peaks: [1199] e mean value 133.98 and stdev 4.168884742949846
# integral 9342.84
# integralMM 9327.606666666668
# integralEXP 7239.911087676192
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 278/278 [00:01<00:00, 154.58it/s]
